# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Pull the maximum available data
ticker = "BTC-USD"
df = yf.download(ticker, period="max")

# 2. Engineer Features (RSI)
window = 14
delta = df['Close'].diff()
up = delta.clip(lower=0)
down = -1 * delta.clip(upper=0)
ema_up = up.ewm(com=window-1, adjust=False).mean()
ema_down = down.ewm(com=window-1, adjust=False).mean()
rs = ema_up / ema_down
df['RSI'] = 100 - (100 / (1 + rs))

# 3. Engineer Features (Bollinger Bands)
df['MA20'] = df['Close'].rolling(window=20).mean()
df['STD20'] = df['Close'].rolling(window=20).std()
df['Upper_Band'] = df['MA20'] + (df['STD20'] * 2)
df['Lower_Band'] = df['MA20'] - (df['STD20'] * 2)

# 4. Data Scientist "Target" Column (Did price go up the next day?)
# Useful for training your Pattern Recognition Model
df['Target_Next_Day_Up'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# 5. Save to CSV
df.to_csv('bitcoin_pattern_recognition_data.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head(30)
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker         BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100
# 2014-09-22  402.152008  406.915985  397.130005  399.100006  24127600
# 2014-09-23  435.790985  441.557007  396.196991  402.092010  45099500
# 2014-09-24  423.204987  436.112000  421.131989  435.751007  30627700
# 2014-09-25  411.574005  423.519989  409.467987  423.156006  26814400
# 2014-09-26  404.424988  414.937988  400.009003  411.428986  21460800
# 2014-09-27  399.519989  406.622986  397.372009  403.556000  15029300
# 2014-09-28  377.181000  401.016998  374.332001  399.471008  23613300
# 2014-09-29  375.467010  385.210999  372.239990  376.928009  32497700
# 2014-09-30  386.944000  390.976990  373.442993  376.088013  34707300
# 2014-10-01  383.614990  391.378998  380.779999  387.427002  26229400
# 2014-10-02  375.071991  385.497009  372.946014  383.988007  21777700
# 2014-10-03  359.511993  377.695007  357.859009  375.181000  30901200
# 2014-10-04  328.865997  364.487000  325.885986  359.891998  47236500
# 2014-10-05  320.510010  341.800995  289.295990  328.915985  83308096
# 2014-10-06  330.079010  345.134003  302.559998  320.389008  79011800
# 2014-10-07  336.187012  339.247009  320.481995  330.584015  49199900
# 2014-10-08  352.940002  354.364014  327.187988  336.115997  54736300
# 2014-10-09  365.026001  382.726013  347.687012  352.747986  83641104
# 2014-10-10  361.562012  375.066986  352.963013  364.687012  43665700
# 2014-10-11  362.299011  367.191010  355.950989  361.362000  13345200
# 2014-10-12  378.549011  379.433014  356.144012  362.605988  17552800
# 2014-10-13  390.414001  397.226013  368.897003  377.920990  35221400
# 2014-10-14  400.869995  411.697998  391.324005  391.691986  38491500
# 2014-10-15  394.773010  402.226990  388.765991  400.954987  25267100
# 2014-10-16  382.556000  398.807007  373.070007  394.518005  26990000
#
# Price             RSI        MA20      STD20  Upper_Band  Lower_Band  \
# Ticker
# Date
# 2014-09-17        NaN         NaN        NaN         NaN         NaN
# 2014-09-18   0.000000         NaN        NaN         NaN         NaN
# 2014-09-19   0.000000         NaN        NaN         NaN         NaN
# 2014-09-20   3.215775         NaN        NaN         NaN         NaN
# 2014-09-21   3.138104         NaN        NaN         NaN         NaN
# 2014-09-22   3.963347         NaN        NaN         NaN         NaN
# 2014-09-23  12.107304         NaN        NaN         NaN         NaN
# 2014-09-24  11.707282         NaN        NaN         NaN         NaN
# 2014-09-25  11.334585         NaN        NaN         NaN         NaN
# 2014-09-26  11.100667         NaN        NaN         NaN         NaN
# 2014-09-27  10.933938         NaN        NaN         NaN         NaN
# 2014-09-28  10.183735         NaN        NaN         NaN         NaN
# 2014-09-29  10.126326         NaN        NaN         NaN         NaN
# 2014-09-30  13.637140         NaN        NaN         NaN         NaN
# 2014-10-01  13.472740         NaN        NaN         NaN         NaN
# 2014-10-02  13.038347         NaN        NaN         NaN         NaN
# 2014-10-03  12.262814         NaN        NaN         NaN         NaN
# 2014-10-04  10.889037         NaN        NaN         NaN         NaN
# 2014-10-05  10.542246         NaN        NaN         NaN         NaN
# 2014-10-06  13.923041  389.910399  35.558666  461.027732  318.793066
# 2014-10-07  16.102590  383.853049  33.740796  451.334641  316.371457
# 2014-10-08  21.940826  380.278049  32.993690  446.265429  314.290669
# 2014-10-09  25.944557  378.789549  32.975772  444.741094  312.838004
# 2014-10-10  25.540219  376.422450  32.394343  441.211135  311.633765
# 2014-10-11  25.805159  374.596350  32.093251  438.782852  310.409849
# 2014-10-12  31.585387  373.416200  31.454238  436.324676  310.507725
# 2014-10-13  35.534481  371.147351  28.184888  427.517127  314.777575
# 2014-10-14  38.882565  370.030602  26.399627  422.829855  317.231348
# 2014-10-15  37.654503  369.190552  25.250414  419.691379  318.689724
# 2014-10-16  35.251898  368.097102  24.091210  416.279522  319.914682
#
# Price      Target_Next_Day_Up
# Ticker
# Date
# 2014-09-17                  0
# 2014-09-18                  0
# 2014-09-19                  1
# 2014-09-20                  0
# 2014-09-21                  1
# 2014-09-22                  1
# 2014-09-23                  0
# 2014-09-24                  0
# 2014-09-25                  0
# 2014-09-26                  0
# 2014-09-27                  0
# 2014-09-28                  0
# 2014-09-29                  1
# 2014-09-30                  0
# 2014-10-01                  0
# 2014-10-02                  0
# 2014-10-03                  0
# 2014-10-04                  0
# 2014-10-05                  1
# 2014-10-06                  1
# 2014-10-07                  1
# 2014-10-08                  1
# 2014-10-09                  0
# 2014-10-10                  1
# 2014-10-11                  1
# 2014-10-12                  1
# 2014-10-13                  1
# 2014-10-14                  0
# 2014-10-15                  0
# 2014-10-16                  1

# %%
df.isnull().sum()
# Out:
# Price               Ticker
# Close               BTC-USD     0
# High                BTC-USD     0
# Low                 BTC-USD     0
# Open                BTC-USD     0
# Volume              BTC-USD     0
# RSI                             1
# MA20                           19
# STD20                          19
# Upper_Band                     19
# Lower_Band                     19
# Target_Next_Day_Up              0
# dtype: int64

# %%
df.columns = df.columns.set_levels(
    [level.str.lower() for level in df.columns.levels]
)

# %%
df.columns
# Out:
# MultiIndex([(             'close', 'btc-usd'),
#             (              'high', 'btc-usd'),
#             (               'low', 'btc-usd'),
#             (              'open', 'btc-usd'),
#             (            'volume', 'btc-usd'),
#             (               'rsi',        ''),
#             (              'ma20',        ''),
#             (             'std20',        ''),
#             (        'upper_band',        ''),
#             (        'lower_band',        ''),
#             ('target_next_day_up',        '')],
#            names=['Price', 'Ticker'])

# %%
df.head()
# Out:
# Price            close        high         low        open    volume  \
# Ticker         btc-usd     btc-usd     btc-usd     btc-usd   btc-usd
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100
#
# Price            rsi ma20 std20 upper_band lower_band target_next_day_up
# Ticker
# Date
# 2014-09-17       NaN  NaN   NaN        NaN        NaN                  0
# 2014-09-18  0.000000  NaN   NaN        NaN        NaN                  0
# 2014-09-19  0.000000  NaN   NaN        NaN        NaN                  1
# 2014-09-20  3.215775  NaN   NaN        NaN        NaN                  0
# 2014-09-21  3.138104  NaN   NaN        NaN        NaN                  1

# %%
df.columns = df.columns.droplevel(1)

# %%
df.head()
# Out:
# Price            close        high         low        open    volume  \
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100
#
# Price            rsi  ma20  std20  upper_band  lower_band  target_next_day_up
# Date
# 2014-09-17       NaN   NaN    NaN         NaN         NaN                   0
# 2014-09-18  0.000000   NaN    NaN         NaN         NaN                   0
# 2014-09-19  0.000000   NaN    NaN         NaN         NaN                   1
# 2014-09-20  3.215775   NaN    NaN         NaN         NaN                   0
# 2014-09-21  3.138104   NaN    NaN         NaN         NaN                   1

# %%
df = df.rename(columns={
    'close': 'close_price',
    'high': 'high_price',
    'low': 'low_price',
    'open': 'open_price'
})

# %%
df = df.dropna(axis=0) # drop missing values

# %%
df
# Out:
# Price        close_price    high_price     low_price    open_price  \
# Date
# 2014-10-06    330.079010    345.134003    302.559998    320.389008
# 2014-10-07    336.187012    339.247009    320.481995    330.584015
# 2014-10-08    352.940002    354.364014    327.187988    336.115997
# 2014-10-09    365.026001    382.726013    347.687012    352.747986
# 2014-10-10    361.562012    375.066986    352.963013    364.687012
# ...                  ...           ...           ...           ...
# 2026-05-16  78131.437500  79173.500000  77630.734375  79066.000000
# 2026-05-17  77429.351562  78539.398438  76783.414062  78133.585938
# 2026-05-18  76954.171875  77749.320312  76029.226562  77426.343750
# 2026-05-19  76750.906250  77346.867188  76082.367188  76954.750000
# 2026-05-20  77334.398438  77481.132812  76499.273438  76757.312500
#
# Price            volume        rsi          ma20        std20    upper_band  \
# Date
# 2014-10-06     79011800  13.923041    389.910399    35.558666    461.027732
# 2014-10-07     49199900  16.102590    383.853049    33.740796    451.334641
# 2014-10-08     54736300  21.940826    380.278049    32.993690    446.265429
# 2014-10-09     83641104  25.944557    378.789549    32.975772    444.741094
# 2014-10-10     43665700  25.540219    376.422450    32.394343    441.211135
# ...                 ...        ...           ...          ...           ...
# 2026-05-16  25895799905  48.887634  79304.302344  1871.007471  83046.317286
# 2026-05-17  20900166465  46.553160  79307.438672  1867.637973  83042.714619
# 2026-05-18  41520471808  44.987372  79337.613672  1821.661250  82980.936173
# 2026-05-19  26031898332  44.300955  79386.352344  1732.201895  82850.756135
# 2026-05-20  25585199104  46.809859  79437.856250  1649.058504  82735.973259
#
# Price         lower_band  target_next_day_up
# Date
# 2014-10-06    318.793066                   1
# 2014-10-07    316.371457                   1
# 2014-10-08    314.290669                   1
# 2014-10-09    312.838004                   0
# 2014-10-10    311.633765                   1
# ...                  ...                 ...
# 2026-05-16  75562.287401                   0
# 2026-05-17  75572.162725                   0
# 2026-05-18  75694.291171                   0
# 2026-05-19  75921.948553                   1
# 2026-05-20  76139.739241                   0
#
# [4245 rows x 11 columns]

# %%
df.close_price.describe()
# Out:
# count      4245.000000
# mean      28598.653411
# std       32409.303484
# min         178.102997
# 25%        3521.101807
# 50%       11584.934570
# 75%       46202.144531
# max      124752.531250
# Name: close_price, dtype: float64

# %%
df['close_price'].hist(bins=50)
plt.title('Distribution of Close Price')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# %%
df[['close_price', 'ma20', 'upper_band', 'lower_band']].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df['close_price'].pct_change().hist(bins=100)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.show()

# %%
df.groupby('target_next_day_up')['rsi'].mean()
# Out:
# target_next_day_up
# 0    52.779575
# 1    53.272830
# Name: rsi, dtype: float64

# %%
df.target_next_day_up.value_counts()
# Out:
# target_next_day_up
# 1    2232
# 0    2013
# Name: count, dtype: int64

# %%
(df[(df['rsi'] < 30)]['target_next_day_up'].mean())
# Out:
# np.float64(0.632258064516129)

# %%
from sklearn.ensemble import RandomForestClassifier

features = df[['rsi', 'ma20', 'std20', 'volume']]
target = df['target_next_day_up']

model = RandomForestClassifier()
model.fit(features, target)

print(model.feature_importances_)
# Out:
# [0.26360876 0.24313195 0.24277213 0.25048716]

# %%
sns.pairplot(df[['rsi', 'close_price', 'target_next_day_up']])

# %% [markdown]
# ### Feature Engineering

# %%
df['return_1'] = df['close_price'].pct_change()
df['return_1']
# Out:
# Date
# 2014-10-06         NaN
# 2014-10-07    0.018505
# 2014-10-08    0.049832
# 2014-10-09    0.034244
# 2014-10-10   -0.009490
#                 ...
# 2026-05-16   -0.011816
# 2026-05-17   -0.008986
# 2026-05-18   -0.006137
# 2026-05-19   -0.002641
# 2026-05-20    0.007602
# Name: return_1, Length: 4245, dtype: float64

# %%
df['hl_range'] = (df['high_price'] - df['low_price']) / df['close_price']

# %%
df['hl_range']
# Out:
# Date
# 2014-10-06    0.128981
# 2014-10-07    0.055817
# 2014-10-08    0.076999
# 2014-10-09    0.095990
# 2014-10-10    0.061135
#                 ...
# 2026-05-16    0.019746
# 2026-05-17    0.022679
# 2026-05-18    0.022352
# 2026-05-19    0.016475
# 2026-05-20    0.012696
# Name: hl_range, Length: 4245, dtype: float64

# %%
df['oc_change'] = (df['close_price'] - df['open_price']) / df['open_price']

# %%
df['oc_change']
# Out:
# Date
# 2014-10-06    0.030244
# 2014-10-07    0.016949
# 2014-10-08    0.050054
# 2014-10-09    0.034807
# 2014-10-10   -0.008569
#                 ...
# 2026-05-16   -0.011820
# 2026-05-17   -0.009013
# 2026-05-18   -0.006098
# 2026-05-19   -0.002649
# 2026-05-20    0.007518
# Name: oc_change, Length: 4245, dtype: float64

# %%
df['body_size'] = abs(df['close_price'] - df['open_price']) / df['close_price']

# %%
df['body_size'].head()
# Out:
# Date
# 2014-10-06    0.029357
# 2014-10-07    0.016666
# 2014-10-08    0.047668
# 2014-10-09    0.033636
# 2014-10-10    0.008643
# Name: body_size, dtype: float64

# %% [markdown]
# ### Trend Features

# %%
df['ma_ratio'] = df['close_price'] / df['ma20']
df['ma_ratio'] # Above 1 -> bullish trend , Below 1 -> bearish
# Out:
# Date
# 2014-10-06    0.846551
# 2014-10-07    0.875822
# 2014-10-08    0.928110
# 2014-10-09    0.963664
# 2014-10-10    0.960522
#                 ...
# 2026-05-16    0.985211
# 2026-05-17    0.976319
# 2026-05-18    0.969958
# 2026-05-19    0.966802
# 2026-05-20    0.973521
# Name: ma_ratio, Length: 4245, dtype: float64

# %%
df['ma_slope'] = df['ma20'].diff() # Direction of trend (rising or falling)
df['ma_slope']
# Out:
# Date
# 2014-10-06          NaN
# 2014-10-07    -6.057350
# 2014-10-08    -3.575000
# 2014-10-09    -1.488499
# 2014-10-10    -2.367099
#                 ...
# 2026-05-16   -26.305078
# 2026-05-17     3.136328
# 2026-05-18    30.175000
# 2026-05-19    48.738672
# 2026-05-20    51.503906
# Name: ma_slope, Length: 4245, dtype: float64

# %%
df[["ma20", "ma_slope"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['price_vs_ma'] = df['close_price'] - df['ma20'] # Distance from trend (overextended or not)
df['price_vs_ma'].tail()
# Out:
# Date
# 2026-05-16   -1172.864844
# 2026-05-17   -1878.087109
# 2026-05-18   -2383.441797
# 2026-05-19   -2635.446094
# 2026-05-20   -2103.457812
# Name: price_vs_ma, dtype: float64

# %%
fig, axes = plt.subplots(2, 1, sharex=True)

df[["close_price", "ma20"]].plot(ax=axes[0], title="Price & MA20")
df["price_vs_ma"].plot(ax=axes[1], title="Price minus MA20")

plt.show()

# %% [markdown]
# ### Volatility features

# %%
df['volatility'] = df['std20'] #Already given — measures market instability

# %%
df['volatility'].hist()
# Out:
# <Axes: >

# %%
df['volatility_change'] = df['std20'].pct_change() # Detects volatility expansion (before big moves)
df['volatility_change'].describe()
# Out:
# count    4244.000000
# mean        0.006961
# std         0.118784
# min        -0.534495
# 25%        -0.045066
# 50%        -0.000108
# 75%         0.045398
# max         2.019265
# Name: volatility_change, dtype: float64

# %% [markdown]
# ### Bollinger Band Features

# %%
df['bb_position'] = (df['close_price'] - df['lower_band']) / (df['upper_band'] - df['lower_band'])

# 0 -> bottom
# 1-> top

df['bb_position'].describe()
# Out:
# count    4245.000000
# mean        0.548882
# std         0.328577
# min        -0.490364
# 25%         0.297270
# 50%         0.556680
# 75%         0.812658
# max         1.515963
# Name: bb_position, dtype: float64

# %%
df['bb_position'].hist()
# Out:
# <Axes: >

# %%
df['bb_width'] = (df['upper_band'] - df['lower_band']) / df['ma20'] 

# Narrow -> breakout coming
# Wide -> volatile market
df['bb_width'].hist()
# Out:
# <Axes: >

# %%
df['bb_breakout_up'] = (df['close_price'] > df['upper_band']).astype(int)
df['bb_breakout_down'] = (df['close_price'] < df['lower_band']).astype(int) # strong breakout signals

# %% [markdown]
# ### RSI features

# %%
df['rsi_overbought'] = (df['rsi'] > 70).astype(int)
df['rsi_oversold'] = (df['rsi'] < 30).astype(int)

# %%
df['rsi_overbought'].value_counts()
# Out:
# rsi_overbought
# 0    3720
# 1     525
# Name: count, dtype: int64

# %%
df['rsi_oversold'].value_counts()
# Out:
# rsi_oversold
# 0    4090
# 1     155
# Name: count, dtype: int64

# %%
df['rsi_change'] = df['rsi'].diff() # Momentum shift
df['rsi_change'].hist()
# Out:
# <Axes: >

# %%
df['rsi_ma_interaction'] = df['rsi'] * df['ma_ratio'] # Nonlinear pattern (very useful)

# %%
df['volume_change'] = df['volume'].pct_change() # Sudden interest in market

# %%
df['volume_spike'] = (df['volume'] > df['volume'].rolling(20).mean()).astype(int) # Unusual activity → often precedes moves

# %%
df['price_volume'] = df['return_1'] * df['volume'] #Combines price + conviction

# %%
df.isnull().sum()
# Out:
# Price
# close_price           0
# high_price            0
# low_price             0
# open_price            0
# volume                0
# rsi                   0
# ma20                  0
# std20                 0
# upper_band            0
# lower_band            0
# target_next_day_up    0
# return_1              1
# hl_range              0
# oc_change             0
# body_size             0
# ma_ratio              0
# ma_slope              1
# price_vs_ma           0
# volatility            0
# volatility_change     1
# bb_position           0
# bb_width              0
# bb_breakout_up        0
# bb_breakout_down      0
# rsi_overbought        0
# rsi_oversold          0
# rsi_change            1
# rsi_ma_interaction    0
# volume_change         1
# volume_spike          0
# price_volume          1
# dtype: int64

# %%
df
# Out:
# Price        close_price    high_price     low_price    open_price  \
# Date
# 2014-10-06    330.079010    345.134003    302.559998    320.389008
# 2014-10-07    336.187012    339.247009    320.481995    330.584015
# 2014-10-08    352.940002    354.364014    327.187988    336.115997
# 2014-10-09    365.026001    382.726013    347.687012    352.747986
# 2014-10-10    361.562012    375.066986    352.963013    364.687012
# ...                  ...           ...           ...           ...
# 2026-05-16  78131.437500  79173.500000  77630.734375  79066.000000
# 2026-05-17  77429.351562  78539.398438  76783.414062  78133.585938
# 2026-05-18  76954.171875  77749.320312  76029.226562  77426.343750
# 2026-05-19  76750.906250  77346.867188  76082.367188  76954.750000
# 2026-05-20  77334.398438  77481.132812  76499.273438  76757.312500
#
# Price            volume        rsi          ma20        std20    upper_band  \
# Date
# 2014-10-06     79011800  13.923041    389.910399    35.558666    461.027732
# 2014-10-07     49199900  16.102590    383.853049    33.740796    451.334641
# 2014-10-08     54736300  21.940826    380.278049    32.993690    446.265429
# 2014-10-09     83641104  25.944557    378.789549    32.975772    444.741094
# 2014-10-10     43665700  25.540219    376.422450    32.394343    441.211135
# ...                 ...        ...           ...          ...           ...
# 2026-05-16  25895799905  48.887634  79304.302344  1871.007471  83046.317286
# 2026-05-17  20900166465  46.553160  79307.438672  1867.637973  83042.714619
# 2026-05-18  41520471808  44.987372  79337.613672  1821.661250  82980.936173
# 2026-05-19  26031898332  44.300955  79386.352344  1732.201895  82850.756135
# 2026-05-20  25585199104  46.809859  79437.856250  1649.058504  82735.973259
#
# Price         lower_band  ...  bb_width  bb_breakout_up  bb_breakout_down  \
# Date                      ...
# 2014-10-06    318.793066  ...  0.364788               0                 0
# 2014-10-07    316.371457  ...  0.351601               0                 0
# 2014-10-08    314.290669  ...  0.347048               0                 0
# 2014-10-09    312.838004  ...  0.348223               0                 0
# 2014-10-10    311.633765  ...  0.344234               0                 0
# ...                  ...  ...       ...             ...               ...
# 2026-05-16  75562.287401  ...  0.094371               0                 0
# 2026-05-17  75572.162725  ...  0.094197               0                 0
# 2026-05-18  75694.291171  ...  0.091844               0                 0
# 2026-05-19  75921.948553  ...  0.087280               0                 0
# 2026-05-20  76139.739241  ...  0.083036               0                 0
#
# Price       rsi_overbought  rsi_oversold  rsi_change  rsi_ma_interaction  \
# Date
# 2014-10-06               0             1         NaN           11.786563
# 2014-10-07               0             1    2.179549           14.103006
# 2014-10-08               0             1    5.838235           20.363508
# 2014-10-09               0             1    4.003731           25.001845
# 2014-10-10               0             1   -0.404338           24.531940
# ...                    ...           ...         ...                 ...
# 2026-05-16               0             0   -3.229260           48.164614
# 2026-05-17               0             0   -2.334474           45.450730
# 2026-05-18               0             0   -1.565788           43.635872
# 2026-05-19               0             0   -0.686416           42.830265
# 2026-05-20               0             0    2.508904           45.570367
#
# Price       volume_change  volume_spike  price_volume
# Date
# 2014-10-06            NaN             0           NaN
# 2014-10-07      -0.377309             0  9.104277e+05
# 2014-10-08       0.112529             0  2.727639e+06
# 2014-10-09       0.528074             0  2.864187e+06
# 2014-10-10      -0.477940             0 -4.143746e+05
# ...                   ...           ...           ...
# 2026-05-16      -0.321804             0 -3.059855e+08
# 2026-05-17      -0.192913             0 -1.878081e+08
# 2026-05-18       0.986610             1 -2.548089e+08
# 2026-05-19      -0.373035             0 -6.876028e+07
# 2026-05-20      -0.017160             0  1.945093e+08
#
# [4245 rows x 31 columns]

# %%
plt.figure(figsize=(18, 18))

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: xlabel='Price', ylabel='Price'>

# %%
df.isnull().sum()
# Out:
# Price
# close_price           0
# high_price            0
# low_price             0
# open_price            0
# volume                0
# rsi                   0
# ma20                  0
# std20                 0
# upper_band            0
# lower_band            0
# target_next_day_up    0
# return_1              1
# hl_range              0
# oc_change             0
# body_size             0
# ma_ratio              0
# ma_slope              1
# price_vs_ma           0
# volatility            0
# volatility_change     1
# bb_position           0
# bb_width              0
# bb_breakout_up        0
# bb_breakout_down      0
# rsi_overbought        0
# rsi_oversold          0
# rsi_change            1
# rsi_ma_interaction    0
# volume_change         1
# volume_spike          0
# price_volume          1
# dtype: int64
